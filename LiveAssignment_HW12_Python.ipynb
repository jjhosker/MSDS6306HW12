# %%
print("########################################")
print("# Live Assignment Homework #12:")
print("#      HTML file for submission")
print("# By:  James Hosker")
print("# For MSDS6306-402 (Thursday 6:30-8:00 PM)")
print("########################################")
print("")
print("** Loaded all packages: sys, os, math, re, types, imp")
print("      numpy, matplotlib,")

## Import Packages
import sys, os, math, re, types, imp
import numpy, matplotlib
import numpy as np
import matplotlib.pyplot as plt

## Always Provide Python system version
print("")
print("** Printout Python Version Below:")
print("  ",sys.version)
print("")
# Out:
# ########################################
# # Live Assignment Homework #12:
# #      HTML file for submission
# # By:  James Hosker
# # For MSDS6306-402 (Thursday 6:30-8:00 PM)
# ########################################
#
# ** Loaded all packages: sys, os, math, re, types, imp
#       numpy, matplotlib,
#
# ** Printout Python Version Below:
#    3.5.2 |Continuum Analytics, Inc.| (default, Jul  5 2016, 11:41:13) [MSC v.1900 64 bit (AMD64)]

# %%
################################################
## Question 1:  Create a list named my_list 
##     in python with the following data points: 
##     45.4 44.2 36.8 35.1 39.0 60.0 47.4 41.1 
##     45.8 35.6
################################################
print('Question 1:  Create a list named my_list in python with the following data points:')
print('45.4 44.2 36.8 35.1 39.0 60.0 47.4 41.1 45.8 35.6')
print("")

###### Question 1a:  Print the 5th element in the list ######
my_list = [45.4, 44.2, 36.8, 35.1, 39.0, 60.0, 47.4, 41.1, 45.8, 35.6]
print("     1.a. The 5th element of nlist is:", my_list[5])
print("")

###### Question 1b:  Append 55.2 to my_list ######
my_list.append(55.2)
print("     1.b. Append 55.2 to nlist:")
print("         ",my_list)
print("")

###### Question 1c:  Remove the 6th element in the list  ######
temp = my_list[6]
del my_list[6]
print("     1.c. Remove the 6th element in nlist (",temp,"):")
print("         ",my_list)
print("")

###### Question 1d:  Iterate over the list to print data ######
######               points greater than 45 ######
gt45list = [i for i in my_list if i > 45]
print("     1.d. Printout elements of  nlist > 45:(",temp,"):")
print("         ",gt45list)
# Out:
# Question 1:  Create a list named my_list in python with the following data points:
# 45.4 44.2 36.8 35.1 39.0 60.0 47.4 41.1 45.8 35.6
#
#      1.a. The 5th element of nlist is: 60.0
#
#      1.b. Append 55.2 to nlist:
#           [45.4, 44.2, 36.8, 35.1, 39.0, 60.0, 47.4, 41.1, 45.8, 35.6, 55.2]
#
#      1.c. Remove the 6th element in nlist ( 47.4 ):
#           [45.4, 44.2, 36.8, 35.1, 39.0, 60.0, 41.1, 45.8, 35.6, 55.2]
#
#      1.d. Printout elements of  nlist > 45:( 47.4 ):
#           [45.4, 60.0, 45.8, 55.2]

# %%
################################################
## Question 2:  Introduction to numpy:
################################################
print('Question 2:  Introduction to numpy:')

###### Question 2a:  Import the numpy library using the following command – import numpy ######
import numpy
print("     2.a. Imported the numpy library:  import numpy")
print("")

###### Question 2b:  Declare numpy array with the same data points as in my_list 
######               using numpy.array() ######
my_nplist = numpy.array(my_list[1:], dtype=np.float)
print("     2.b. Declare numpy array with the same data points as in") 
print("          my_list using numpy.array():")
print("         ",my_nplist)
print("")

###### Question 2c:  Compute the mean and standard deviation using numpy.mean() 
######               and numpy.std() of the above array ######
print("     2.c. Compute the mean of my_nplist:", round(numpy.mean(my_nplist),3)) 
print("          Compute the std. dev. of my_nplist:", round(numpy.std(my_nplist),3)) 
print("")

      
###### Question 2d:  Use logical referencing to get only those values that are ###### 
######               less than 45 ######
lt45nplist = [i for i in my_nplist if i < 45]
print("     2.d. Printout elements in my_nplist < 45:")
## format_lt45nplist = [ '%.3f' % j for j in lt45nplist ]
print("         ",lt45nplist)
print("")

###### Question 2e:  Compute the max and min of the array using numpy.max() 
######               and numpy.min() ######
print("     2.e. Compute the numpy.max() of my_nplist:", round(numpy.max(my_nplist),3)) 
print("          Compute the numpy.min() of my_nplist:", round(numpy.min(my_nplist),3))
# Out:
# Question 2:  Introduction to numpy:
#      2.a. Imported the numpy library:  import numpy
#
#      2.b. Declare numpy array with the same data points as in
#           my_list using numpy.array():
#           [ 44.2  36.8  35.1  39.   60.   41.1  45.8  35.6  55.2]
#
#      2.c. Compute the mean of my_nplist: 43.644
#           Compute the std. dev. of my_nplist: 8.291
#
#      2.d. Printout elements in my_nplist < 45:
#           [44.200000000000003, 36.799999999999997, 35.100000000000001, 39.0, 41.100000000000001, 35.600000000000001]
#
#      2.e. Compute the numpy.max() of my_nplist: 60.0
#           Compute the numpy.min() of my_nplist: 35.1

# %%
################################################
## Question 3:  Introduction to pandas:
################################################
print('Question 3:  Introduction to pandas:')
print("")

###### Question 3a:  Import the pandas library – import pandas ######
import pandas
print("     3.a. Imported the pandas library:  import pandas")
print("")

###### Question 3b:  Read the IRIS dataset into iris using pandas.read_csv(). 
######               Data file –  ######
print("     3.b. Sucessfully read in Iris.csv file as iris dataset")
#####################################################################
## Change to directory where file is located using your directory name
os.chdir('C:\\Users\\JHosker\\Documents\\PythonProj\\MSDS6306HW12')
## print(os.getcwd())  ## print directory
#####################################################################

## Read in Iris.csv file after changing directory above
iris = pandas.read_csv("Iris.csv")
print("")

###### Question 3c:  Using iris.head(), display the head of the dataset
print("     3.c. Display iris.head() of iris dataset:")
print(iris.head())
print("")

###### Question 3d:  Use DataFrame.drop() to drop the id column
print("     3.d. Use DataFrame.drop() to drop the Id column")
print("          and print iris.head() to show it is removed:")
iris = iris.drop('Id', 1)
print(iris.head())
print("")

###### Question 3e:  Subset dataframe to create a new data frame that
######               includes only the measurements for the setosa species
iris_setosa = iris.loc[iris['Species']=='Iris-setosa']
print("     3.e. We create a subset dataframe (iris_setosa) that includes")
print("          only setosa species and the iris_setosa.head() printed below:")
print(iris_setosa.head())
print("")

###### Question 3f:  Use DataFrame.describe() to get the summary statistics
print("     3.f. We printout iris_setosa.describe() for summary stats below:")
print(iris_setosa.describe())
print("")

###### Question 3g:  Use DataFrame.groupby() to create grouped data frames by 
######               Species and compute summary statistics using 
######               DataFrame.describe()
iris_SpeciesByGrp = iris.groupby(['Species'])
print("     3.g. Use iris.groupby() to create grouped data frames by") 
print("          Species and compute/print summary statistics")
print("          using iris.describe():")
print(iris_SpeciesByGrp.describe())
print("")

###### Question 3h:  Use DataFrame.boxplot() to plot boxplots by Species
print("     3.h. Use iris.boxplot() to plot boxplots by Species categories:") 
## create new column to reduce Species label size
shortlabel = []
# For each row in the column,
for i in iris['Species']:
    if i == 'Iris-setosa':
        shortlabel.append('setosa')
    elif i == 'Iris-versicolor':
        shortlabel.append('versicolor')
    elif i == 'Iris-virginica':
        shortlabel.append('virginica')

iris['SpecLabel'] = shortlabel
iris.boxplot(by='SpecLabel')
print("")
plt.show()
print("")

###### Question 3i:  Plot a scatter matrix plot using the seaborn library. 
######               Use the following to load and plot 
######               i. Import seaborn
######               ii. Seaborn.pairplot(dataframe,by=’column_name’)
import seaborn as sns
print("     3.i. #i. Imported the seaborn library as sns:  import seaborn as sns")
print("")

print("     3.i. #ii. Run sns.pairplot(iris,hue='SpecLabel')")
sns.pairplot(iris,hue='Species')
print("")
plt.show()
print("")

## Here is the code for part (i)
## import seaborn as sns
## sns.pairplot(iris,hue='Species')

## Deliverable is a link to Jupiter notebook file on GitHub.
print("")
urlink_gitHW12= "https://github.com/jjhosker/MSDS6306HW12"
print("Link to Jupiter notebook file on Github repository URL below: ")
print(urlink_gitHW12)
print("View README.md file in Github repository.")
# Out:
# Question 3:  Introduction to pandas:
#
#      3.a. Imported the pandas library:  import pandas
#
#      3.b. Sucessfully read in Iris.csv file as iris dataset
#
#      3.c. Display iris.head() of iris dataset:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
#
#      3.d. Use DataFrame.drop() to drop the Id column
#           and print iris.head() to show it is removed:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# ...
